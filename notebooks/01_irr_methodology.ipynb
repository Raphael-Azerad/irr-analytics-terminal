# %% [markdown]
# # IRR Methodology
#
# This notebook documents the capital-budgeting logic used by IRR Analytics Terminal. It emphasizes that IRR should be interpreted beside NPV, MIRR, payback, scale, timing, and cash-flow pattern.

# %%
from irr_terminal.calculations import calculate_metrics
from irr_terminal.examples import EXAMPLES

metrics = calculate_metrics(EXAMPLES['Corporate Expansion Project'], 0.10, 0.10)
metrics
